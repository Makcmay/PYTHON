# %%
import pandas as pd

# Считываем CSV файл с контактами из телефона
contacts_phone = pd.read_csv('contacts.csv')

# Считываем Excel файл с дополнительной информацией о контактах
contacts_excel = pd.read_excel('Выборн.xlsx', names=['name', 'tel'])

# # Объединяем данные из CSV и Excel файлов по полю 'Имя' контакта
merged_contacts = contacts_phone.merge(contacts_excel, on='Unnamed: 2', how='left')

# # Сохраняем объединенные контакты в новый CSV файл
# merged_contacts.to_csv('merged_contacts.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 10
#       7 contacts_excel = pd.read_excel('Выборн.xlsx', names=['name', 'tel'])
#       9 # # Объединяем данные из CSV и Excel файлов по полю 'Имя' контакта
# ---> 10 merged_contacts = contacts_phone.merge(contacts_excel, on='Unnamed: 2', how='left')
#      12 # # Сохраняем объединенные контакты в новый CSV файл
#      13 # merged_contacts.to_csv('merged_contacts.csv', index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
# ...

# %%
contacts_excel
# Out:
#                                                    name          tel
# № п/п сотр комментарии                              ФИО     Телефон
# NaN        NaN                                      NaN          NaN
# 1          Труфанова             Берман Юлия Алексеевна  79629483909
# 2          Труфанова            Берулава Илья Хвичаевич  79257200622
# 3          Труфанова          Бубнов Константин Юрьевич  79037329714
# ...                                                 ...          ...
# 371        Титова           Чернов Александр Дмитриевич  79152243672
# 372        Титова            Чернет Владимир Валерьевич  79032544576
# 373        Титова        Григоренко Светлана Вадимовна   79263906881
# 374        Титова       Колесникова Мария Александровна  79629326114
# 375        Титова          Капустян Виктор Владимирович  79037991234
#
# [377 rows x 2 columns]

# %%
contacts_phone
# Out:
#                   Name Given Name Additional Name Family Name  Yomi Name  \
# 0           Apple Hill      Apple             NaN        Hill        NaN
# 1       Draw up studio       Draw              up      studio        NaN
# 2              Finkont    Finkont             NaN         NaN        NaN
# 3                  HRD        HRD             NaN         NaN        NaN
# 4        Maша Фотограф       Maша             NaN    Фотограф        NaN
# ..                 ...        ...             ...         ...        ...
# 324      Юля Воробьева        Юля             NaN   Воробьева        NaN
# 325  Юля Дизайн Студия        Юля          Дизайн      Студия        NaN
# 326       Юля Ромашкан        Юля             NaN    Ромашкан        NaN
# 327    Юрий Николаевич       Юрий             NaN  Николаевич        NaN
# 328   Яценко Анастасия     Яценко             NaN   Анастасия        NaN
#
#      Given Name Yomi  Additional Name Yomi  Family Name Yomi  Name Prefix  \
# ...

# %%
# import pandas as pd

# # Read CSV file
csv_file = pd.read_csv('contacts.csv')

# # Read Excel file
excel_file = pd.read_excel('Выборн.xlsx', names=['name', 'phone'])

# # Merge data based on 'name' field in CSV and 'ФИО' field in Excel

merged_data = csv_file.merge(excel_file, left_on='name', right_on='name', how='left')

# # Save the merged data to a new CSV file
# merged_data.to_csv('merged_contacts.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[13], line 11
#       7 excel_file = pd.read_excel('Выборн.xlsx', names=['name', 'phone'])
#       9 # Merge data based on 'name' field in CSV and 'ФИО' field in Excel
# ---> 11 merged_data = csv_file.merge(excel_file, left_on='name', right_on='name', how='left')
#      13 # Save the merged data to a new CSV file
#      14 merged_data.to_csv('merged_contacts.csv', index=False)
#
# File ~/Library/Python/3.9/lib/python/site-packages/pandas/core/frame.py:10093, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10074 @Substitution("")
#   10075 @Appender(_merge_doc, indents=2)
#   10076 def merge(
#    (...)
#   10089     validate: str | None = None,
#   10090 ) -> DataFrame:
#   10091     from pandas.core.reshape.merge import merge
# ...

# %%
excel_file
# Out:
#                                                    name        phone
# № п/п сотр комментарии                              ФИО     Телефон
# NaN        NaN                                      NaN          NaN
# 1          Труфанова             Берман Юлия Алексеевна  79629483909
# 2          Труфанова            Берулава Илья Хвичаевич  79257200622
# 3          Труфанова          Бубнов Константин Юрьевич  79037329714
# ...                                                 ...          ...
# 371        Титова           Чернов Александр Дмитриевич  79152243672
# 372        Титова            Чернет Владимир Валерьевич  79032544576
# 373        Титова        Григоренко Светлана Вадимовна   79263906881
# 374        Титова       Колесникова Мария Александровна  79629326114
# 375        Титова          Капустян Виктор Владимирович  79037991234
#
# [377 rows x 2 columns]
